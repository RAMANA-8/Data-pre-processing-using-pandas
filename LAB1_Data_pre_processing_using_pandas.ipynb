# %%
#packge installing
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import the need packages
import pandas as pd

# %%
#Uploading data into dataframe
df = pd.read_csv("D:\Jeyashri\IBM\Datasets\Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0            19000        NaN
# 1    15810944    Male  35.0            20000        0.0
# 2    15668575  Female  26.0            43000        0.0
# 3    15603246  Female  27.0            57000        0.0
# 4    15804002    Male  19.0            76000        0.0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0            41000        1.0
# 396  15706071    Male  51.0            23000        1.0
# 397  15654296  Female  50.0            20000        1.0
# 398  15755018    Male  36.0            33000        0.0
# 399  15594041  Female  49.0            36000        1.0
#
# [400 rows x 5 columns]

# %%
# Fill missing values with a specific value
df = df.fillna(2)
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0            19000        2.0
# 1    15810944    Male  35.0            20000        0.0
# 2    15668575  Female  26.0            43000        0.0
# 3    15603246  Female  27.0            57000        0.0
# 4    15804002    Male  19.0            76000        0.0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0            41000        1.0
# 396  15706071    Male  51.0            23000        1.0
# 397  15654296  Female  50.0            20000        1.0
# 398  15755018    Male  36.0            33000        0.0
# 399  15594041  Female  49.0            36000        1.0
#
# [400 rows x 5 columns]

# %%
# Drop rows with missing values
df = df.dropna()
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0            19000        2.0
# 1    15810944    Male  35.0            20000        0.0
# 2    15668575  Female  26.0            43000        0.0
# 3    15603246  Female  27.0            57000        0.0
# 4    15804002    Male  19.0            76000        0.0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0            41000        1.0
# 396  15706071    Male  51.0            23000        1.0
# 397  15654296  Female  50.0            20000        1.0
# 398  15755018    Male  36.0            33000        0.0
# 399  15594041  Female  49.0            36000        1.0
#
# [400 rows x 5 columns]

# %%
# Interpolate missing values
df = df.interpolate()
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0            19000        2.0
# 1    15810944    Male  35.0            20000        0.0
# 2    15668575  Female  26.0            43000        0.0
# 3    15603246  Female  27.0            57000        0.0
# 4    15804002    Male  19.0            76000        0.0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0            41000        1.0
# 396  15706071    Male  51.0            23000        1.0
# 397  15654296  Female  50.0            20000        1.0
# 398  15755018    Male  36.0            33000        0.0
# 399  15594041  Female  49.0            36000        1.0
#
# [400 rows x 5 columns]

# %%
# Remove duplicate rows
df = df.drop_duplicates()
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0            19000        2.0
# 1    15810944    Male  35.0            20000        0.0
# 2    15668575  Female  26.0            43000        0.0
# 3    15603246  Female  27.0            57000        0.0
# 4    15804002    Male  19.0            76000        0.0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0            41000        1.0
# 396  15706071    Male  51.0            23000        1.0
# 397  15654296  Female  50.0            20000        1.0
# 398  15755018    Male  36.0            33000        0.0
# 399  15594041  Female  49.0            36000        1.0
#
# [400 rows x 5 columns]

# %%
# One-hot encoding categorical columns
df = pd.get_dummies(df, columns=['Gender'])
df
# Out:
#       User ID   Age  EstimatedSalary  Purchased  Gender_2  Gender_Female  \
# 0    15624510  19.0            19000        2.0         0              0
# 1    15810944  35.0            20000        0.0         0              0
# 2    15668575  26.0            43000        0.0         0              1
# 3    15603246  27.0            57000        0.0         0              1
# 4    15804002  19.0            76000        0.0         0              0
# ..        ...   ...              ...        ...       ...            ...
# 395  15691863  46.0            41000        1.0         0              1
# 396  15706071  51.0            23000        1.0         0              0
# 397  15654296  50.0            20000        1.0         0              1
# 398  15755018  36.0            33000        0.0         0              0
# 399  15594041  49.0            36000        1.0         0              1
#
#      Gender_Male
# 0              1
# 1              1
# 2              0
# 3              0
# 4              1
# ..           ...
# 395            0
# 396            1
# 397            0
# 398            1
# 399            0
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Standardize numerical columns
scaler = StandardScaler()
df[""EstimatedSalary"] = scaler.fit_transform(df["EstimatedSalary"])
# Out:
#   File "<ipython-input-2-c5291834f394>", line 5
#     df[""EstimatedSalary"] = scaler.fit_transform(df["EstimatedSalary"])
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 5)
